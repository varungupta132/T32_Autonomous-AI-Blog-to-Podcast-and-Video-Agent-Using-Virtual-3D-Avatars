# %%
import requests

url = "https://api.heygen.com/v2/video/generate"

headers = {
    "X-Api-Key": "sk_V2_hgu_kqh6Lbg1gkj_bSO7dKuwtMDaMpQT2dMx2kUl2AdQPszi",   # 🔒 put your key here safely
    "Content-Type": "application/json"
}

data = {
    "video_inputs": [
        {
            "character": {
                "type": "avatar",
                "avatar_id": "Anna_public_3"   # example avatar
            },
            "voice": {
                "type": "text",
                "input_text": "Hello Varun, welcome to HeyGen API!",
                "voice_id": "en-US-JennyNeural"
            }
        }
    ]
}

response = requests.post(url, json=data, headers=headers)

print(response.json())
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 26
#       5 headers = {
#       6     "X-Api-Key": "sk_V2_hgu_kqh6Lbg1gkj_bSO7dKuwtMDaMpQT2dMx2kUl2AdQPszi",   # 🔒 put your key here safely
#       7     "Content-Type": "application/json"
#       8 }
#      10 data = {
#      11     "video_inputs": [
#      12         {
#    (...)     23     ]
#      24 }
# ---> 26 response = requests.post(url, json=data, headers=headers)
#      28 print(response.json())
#
# File c:\Users\gupta\AppData\Local\Programs\Python\Python313\Lib\site-packages\requests\api.py:115, in post(url, data, json, **kwargs)
#     103 def post(url, data=None, json=None, **kwargs):
#     104     r"""Sends a POST request.
#     105
#     106     :param url: URL for the new :class:`Request` object.
#    (...)    112     :rtype: requests.Response
#     113     """
# ...

# %%
import requests

url = "https://api.heygen.com/v2/video/generate"

headers = {
    "X-Api-Key": "sk_V2_hgu_kqh6Lbg1gkj_bSO7dKuwtMDaMpQT2dMx2kUl2AdQPszi",
    "Content-Type": "application/json"
}

data = {
    "video_inputs": [
        {
            "character": {
                "type": "avatar",
                "avatar_id": "Abigail_expressive_2024112501"   # ✅ correct avatar
            },
            "voice": {
                "type": "text",
                "input_text": "Hello Varun, your HeyGen API is working perfectly!",
                "voice_id": "en-US-JennyNeural"
            }
        }
    ]
}

response = requests.post(url, json=data, headers=headers)
print(response.json())
# Out:
# {'error': None, 'data': {'video_id': 'aa9c40c1706a41bab2614b8b25325e68'}}

# %%
sk_V2_hgu_kqh6Lbg1gkj_bSO7dKuwtMDaMpQT2dMx2kUl2AdQPszi

# %%
import requests
import time

video_id = "aa9c40c1706a41bab2614b8b25325e68"

url = f"https://api.heygen.com/v1/video_status.get?video_id={video_id}"

headers = {
    "X-Api-Key": "sk_V2_hgu_kqh6Lbg1gkj_bSO7dKuwtMDaMpQT2dMx2kUl2AdQPszi"
}

while True:
    response = requests.get(url, headers=headers)

    print("Status Code:", response.status_code)
    print("Response:", response.text)

    try:
        data = response.json()
    except:
        print("❌ Not JSON, retrying...")
        time.sleep(5)
        continue

    status = data.get("data", {}).get("status")
    print("Status:", status)

    if status == "completed":
        print("🎥 Video URL:", data["data"]["video_url"])
        break

    elif status == "failed":
        print("❌ Failed")
        break

    time.sleep(5)
# Out:
# Status Code: 200
# Response: {"code":100,"data":{"callback_id":null,"caption_url":null,"created_at":1774028340,"duration":null,"error":{"activity_name":"TemporalCoreActivity.COMPLETE_SCRIPT_METADATA","code":"TTS_VOICE_UNAVAILABLE_ERR","detail":"voice_id=en-US-JennyNeural: Voice not found, id: en-US-JennyNeural","exception_class":"MovioException","message":"Voice validation failed for 1 voice(s)"},"gif_url":null,"id":"aa9c40c1706a41bab2614b8b25325e68","status":"failed","thumbnail_url":null,"video_url":null,"video_url_caption":null},"message":"Success"}
#
# Status: failed
# ❌ Failed

# %%
import requests
import time

API_KEY = "sk_V2_hgu_kqh6Lbg1gkj_bSO7dKuwtMDaMpQT2dMx2kUl2AdQPszi"

headers = {
    "X-Api-Key": API_KEY,
    "Content-Type": "application/json"
}

# Step 1: Generate video using Video Agent
url = "https://api.heygen.com/v2/video_agent/generate"

data = {
    "prompt": "A girl explaining AI in simple words",
    "title": "AI Explanation Video"
}

response = requests.post(url, json=data, headers=headers)
print("Generate Response:", response.text)

video_id = response.json()["data"]["video_id"]

# Step 2: Check status
status_url = f"https://api.heygen.com/v1/video_status.get?video_id={video_id}"

while True:
    res = requests.get(status_url, headers=headers)
    data = res.json()

    status = data.get("data", {}).get("status")
    print("Status:", status)

    if status == "completed":
        print("🎥 Video URL:", data["data"]["video_url"])
        break
    elif status == "failed":
        print("❌ Failed:", data["data"]["error"])
        break

    time.sleep(5)
# Out:
# Generate Response: <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 3.2 Final//EN">
# <title>404 Not Found</title>
# <h1>Not Found</h1>
# <p>The requested URL was not found on the server. If you entered the URL manually please check your spelling and try again.</p>
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File c:\Users\gupta\AppData\Local\Programs\Python\Python313\Lib\site-packages\requests\models.py:976, in Response.json(self, **kwargs)
#     975 try:
# --> 976     return complexjson.loads(self.text, **kwargs)
#     977 except JSONDecodeError as e:
#     978     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     979     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# ...
